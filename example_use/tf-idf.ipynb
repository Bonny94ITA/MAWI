# %%
from polyfuzz import PolyFuzz

from_list = ["Biblioteca civica centrale",  
"Biblioteca dell'Accademia delle Scienze", \
"Biblioteca dell'Archivio di Stato", \
"Biblioteca della Fondazione Luigi Einaudi", \
"Biblioteca della Scuola di Applicazione dell'Esercito", \
"Biblioteca Interdipartimentale di Scienze Religiose Erik Peterson", \
"Biblioteca internazionale di Cinema", \
"Biblioteca Nazionale", \
"Biblioteca Nazionale del Club Alpino Italiano", \
"Biblioteca nazionale di Torino", \
"Biblioteca Provinciale dei Frati minori cappuccini"]

model = PolyFuzz("EditDistance")
model.match(from_list)

# %%
model.get_matches()
# Out:
#                                                  From  \
# 0                          Biblioteca civica centrale
# 1             Biblioteca dell'Accademia delle Scienze
# 2                   Biblioteca dell'Archivio di Stato
# 3           Biblioteca della Fondazione Luigi Einaudi
# 4   Biblioteca della Scuola di Applicazione dell'E...
# 5   Biblioteca Interdipartimentale di Scienze Reli...
# 6                 Biblioteca internazionale di Cinema
# 7                                Biblioteca Nazionale
# 8       Biblioteca Nazionale del Club Alpino Italiano
# 9                      Biblioteca nazionale di Torino
# 10  Biblioteca Provinciale dei Frati minori cappuc...
#
#                                                    To  Similarity
# 0             Biblioteca dell'Accademia delle Scienze       0.855
# 1   Biblioteca Interdipartimentale di Scienze Reli...       0.855
# 2   Biblioteca della Scuola di Applicazione dell'E...       0.855
# ...
